# %% [markdown]
# # Functions
#
# Theory Questions
#
# 1--What is the difference between a function and a method in Python?
# << A Function is a block of reusable code that performs a specific task and it is defined using the "def" keyword (or lambda for anonymous functions). also functions can exist on their own means they are not attached to any object.
# whereas a Method is like a function but it's associated with an object. A method is defined inside a class and is called on an Object also Methods implicitly take the object (self) as their first argument.
#
# 2-- Explain the concept function arguments and parameters in Python.
# << Functions arguments are the actual values we pass to the function when calling it means informations can be passed into functions as arguments.
# and Function Parameters are the Placeholders defined in the function definition.
#
# 3-- What are the different ways to define and call a function in Python.?
# << Functions can be defined by using def keyword, *args(for multiple positional arguments),**kwargs(for multiple keyword arguments), Lambda (for Anonymous Function).
# After creating a function in Python we can call it by using the name of the functions Python followed by paranthesis containing parameters of that particular functions example-- def fun():
#                               print("Welcome to Python")
#                               fun()
#                           Output-- Welcome to Python
#
# 4-- What is the purpose of the 'Return' statement in a python functions ?
# << The purpose of 'Return' functions are given below-
#    - return gives back a result
#    - return exits the function.
#    - If we don't return anything, Python returns None by default.
#
# 5-- What are iterators in Python and how do they are different from iterables?
# << Iterator in python is an object that is used to iterate over iterable objects like lists, tuples, dicts, and sets.The iterator object is initialized using the `iter()` method. It uses the `next()` method for iteration. whereas iterable is any object that can return its elements one at a time . Iterators are different from iterables as they're the actual objects that does the work of iterating.
#
#
# 6-- Explain the concept of generators in Python and how they are defined?
# <<  - Generator functions in Python are a way to create iterators in a more concise and memory-efficient manner.
#    - These functions allow you to iterate over a potentially large sequence of data without loading the entire sequence into memory.
#    - The main difference between a regular function and a generator function is that the latter uses the yield keyword to produce a series of values over time, one at a time, rather than returning a single result.
#     A generator functions uses yield instead of return to define it.(Each yield returns a value and pauses the functions)
#
# 7-- What are the advantages of using generator over regular functions?
# << Generator offer several advantages over regular functions like it has a better Memory Efficiency,They can handle infinite sequences , Lazy Evaluation,it has better code simplicity and readability, also it perform Resumable execution(by help of Yield) .
#
# 8-- What is a lambda function in Python and when it is typically used?
# << A lambda functions is a small anonymous function created using the    lambda keyword.It can take any number of arguments, but can only have one expression.
#  Syntax -- lambda arguments : expression
#     They are typically used in situations where a small function is needed for a small function for a short period of time and defining a full function would be overkill. map(),filter(),sorted(),reduce() are the typical usecases for this.
#
# 9-- Explain the purpose and usage of of the 'map'functions in python?
# <<  The map() functions in python is used to apply a function to every item in an iterables (like a list ,tuple etc)and returns a map object (which is an iterator). It's purpose is to simplify and speedup transformations on sequences also it avoids the need for writing for loops manually when we want to apply the same operation to each item in a collection.
#      Syntax- map(function,iterable)
#
# 10-- What is the difference between 'map()', 'reduce()' and 'filter()'functions in python?
# << 'map()' function returns a map object(which is an iterator) of the results after applying the given function to each item of a given iterables(list,tuple)
#    'reduce()' function is used to apply a particular function passed in its argument to all of the list elements mentioned in the sequence passed along . this function is defined in "functools" module.
#    'filter()' function filters the given sequence with the help of a function that tests each element in the sequence to be true or not.

# %% [markdown]
# 11-- Using pen and paper write the internal mechanism for sum operation using reduce function on this given list: [47,11,42,13];

# %% [markdown]
# ![WhatsApp Image 2025-07-30 at 08.01.02_e0dfa2de.jpg](data:image/jpeg;base64,...)

# %%
#1-- Write a python function that takes a list of numbers as input and returns the sum of all even numbers in the list
def sum_of_even_numbers(numbers):
  total = 0
  for num in numbers:
    if num % 2 == 0:
      total += num
  return total

my_list = [5,6,8,10,12]
result = sum_of_even_numbers(my_list)
print("The sum of even numbers is:", result)
# Out:
# The sum of even numbers is: 36

# %%
#2-- Create a python function that accepts a string and returns the reverse of that string.
def reverse_string_recursive(input_str):
   if len(input_str) <= 1:
      return input_str
   return reverse_string_recursive(input_str[1:])+ input_str[0]
input_string = "Hello, World!"
result = reverse_string_recursive(input_string)
print ("Original string:", input_string)
print ("Reversed string:", result)
# Out:
# Original string: Hello, World!
# Reversed string: !dlroW ,olleH

# %%
#3-- Implement a Python function that takes a list of integers and return a new list containing the squares of each number
def square_numbers(numbers):
    return [x ** 2 for x in numbers]
nums = [2,4,6,8,16,18,28]
squared = square_numbers(nums)
print (squared)
# Out:
# [4, 16, 36, 64, 256, 324, 784]

# %%
#4-- Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n <=1:
        return False
    if n ==2:
        return True
    if n%2 == 0:
        return False
    for i in range(3, int(n**0.5)+1,2):
        if n % i== 0:
          return False
        return True
for num in range(1,201):
    if is_prime(num):
         print(f"{num} is a prime number")
# Out:
# 2 is a prime number
# 11 is a prime number
# 13 is a prime number
# 17 is a prime number
# 19 is a prime number
# 23 is a prime number
# 25 is a prime number
# 29 is a prime number
# 31 is a prime number
# 35 is a prime number
# 37 is a prime number
# 41 is a prime number
# 43 is a prime number
# 47 is a prime number
# 49 is a prime number
# 53 is a prime number
# 55 is a prime number
# 59 is a prime number
# 61 is a prime number
# 65 is a prime number
# 67 is a prime number
# 71 is a prime number
# 73 is a prime number
# 77 is a prime number
# 79 is a prime number
# 83 is a prime number
# 85 is a prime number
# 89 is a prime number
# 91 is a prime number
# 95 is a prime number
# 97 is a prime number
# 101 is a prime number
# 103 is a prime number
# 107 is a prime number
# 109 is a prime number
# 113 is a prime number
# 115 is a prime number
# 119 is a prime number
# 121 is a prime number
# 125 is a prime number
# 127 is a prime number
# 131 is a prime number
# 133 is a prime number
# ...

# %%
#5-- Create an iterator class in python that generates the Fibonacci sequence up to a specified number of terms.
class FibonacciIterator:
    def __init__(self, num_terms):
        self.num_terms = num_terms
        self.count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.num_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.a

# Example usage:
fib = FibonacciIterator(10)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
#6-- Write a generator function in python that yields the power of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for exponent in range(max_exponent + 1):
        yield 2 ** exponent
for value in powers_of_two(9):
    print(value)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %%
#7-- Implement a generator function that reads a file line by line and yields each lines as a string.

# %%
L = ["Brij\n", "Kishore\n", "Singh\n"]

file1 = open('myfile.txt', 'w')
file1.writelines(L)
file1.close()

file1 = open('myfile.txt', 'r')
count = 0

print("Using the loop")
for line in file1:
    count += 1
    print("Line{}: {}".format(count, line.strip()))

file1.close()
# Out:
# Using the loop
# Line1: Brij
# Line2: Kishore
# Line3: Singh

# %%
#8-- Use a lambda function in python to sort a list of tuples based on the second element of each tuple
my_list = [(1, 3), (2, 1), (4, 2), (5, 0)]

# Sort using a lambda function as the key
sorted_list = sorted(my_list, key=lambda x: x[1])

print("Original list:", my_list)
print("Sorted list (by second element):", sorted_list)
# Out:
# Original list: [(1, 3), (2, 1), (4, 2), (5, 0)]
# Sorted list (by second element): [(5, 0), (2, 1), (4, 2), (1, 3)]

# %%
#9-- Create a Python program that uses 'map()' to convert a list of temperature from celsius to Fahrenheit

# %%
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temps = [0, 20, 37, 100]

# Use map to convert to Fahrenheit
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))

print("Temperatures in Celsius:", celsius_temps)
print("Temperatures in Fahrenheit:", fahrenheit_temps)
# Out:
# Temperatures in Celsius: [0, 20, 37, 100]
# Temperatures in Fahrenheit: [32.0, 68.0, 98.6, 212.0]

# %%
#10-- Create a Python program that uses 'filter()' to remove all the vowels from a given string

# %%
def is_not_vowel(char):
    return char.lower() not in 'aeiou'

# Input string
input_string = "Hello World"

# Use filter to remove vowels
result = ''.join(filter(is_not_vowel, input_string))

print("Original string:", input_string)
print("String without vowels:", result)
# Out:
# Original string: Hello World
# String without vowels: Hll Wrld

# %%
#11-- Imagine an accounting routine used in a book shop. it works on a list with sublists, which look like this:
# order number     Book Title and Author                       Quantity              Price per item
# 34587            Learning Python,Mark  Lutz                    4                     40.95
# 98762            Programming Python,Mark Lutz                  5                     56.80
# 77226            Head First Python , Paul Barry                3                     32.95
# 88112            Einfuhrung in Python3, Bernd Klein            3                     24.99

# Write a Python Program, which returns a list with 2-tuples.Each tuple consists of the order number and the product of the price per item and
# the quantity .The product should be increased by 10,-E if the values of the order is smaller than 100,00 E
# write a Python program using Lambda and map

# %%
# Order data: (order_number, book_title, quantity, price_per_item)
orders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
]

# Use map and lambda to create the result
order_totals = list(map(
    lambda order: (
        order[0],  # Order Number
        round(order[2] * order[3] + (10 if order[2] * order[3] < 10000 else 0), 2)
    ),
    orders
))

print(order_totals)
# Out:
# [(34587, 173.8), (98762, 294.0), (77226, 108.85), (88112, 84.97)]
